# %% [markdown]
# # Pre-processing Notebook
# - Input for this notebook: SCSE faculty staff DBLP info XML as input
# - Task: Select correct network representation
# - Output: process and create faculty network for analysis (assuming dataflow methodology, a network should be returned

# %%
import networkx as nx
import pandas as pd
import numpy as np
from itertools import combinations
import matplotlib.pyplot as plt

# %%
# Import faculty details into df
faculty_df = pd.read_excel('Faculty.xlsx')

# Select relevant columns
faculty_df = faculty_df[['Faculty', 'Position', 'Gender', 'Management', 'DBLP', 'Area']]

# Create dictionary
faculty_dict = faculty_df.to_dict('index')

# Declare empty List
faculty_list = []

'''
# each[1] corresponds to lumped meta data
# each[1]['Faculty'] corresonds to 'Faculty'
# each[1]['Position'] corresonds to 'Position'
# each[1]['Gender'] corresonds to 'Gender'
# each[1]['Management'] corresponds to 'Management'
# each[1]['DBLP'] corresponds to 'DBLP'
# each[1]['Area'] corresponds to 'Area'
'''
# Iterate over faculty_dict to fill up faculty_list
for each in faculty_dict.items():
    
    node_no = each[0] 
    faculty = each[1]['Faculty']
    position = each[1]['Position']
    gender = each[1]['Gender']
    management = each[1]['Management']
    dblp = each[1]['DBLP']
    area = each[1]['Area']
    
    faculty_list.append((node_no, {'Faculty': faculty}))
    faculty_list.append((node_no, {'Position': position}))
    faculty_list.append((node_no, {'Gender': gender}))
    faculty_list.append((node_no, {'Management': management}))
    faculty_list.append((node_no, {'DBLP': dblp}))
    faculty_list.append((node_no, {'Area': area}))
    
# Declare empty new graph for faculty network
faculty_graph = nx.Graph()

# Fill up empty graph w/ faculty_list
faculty_graph.add_nodes_from(faculty_list)

# %%
###
# compare internal vs external collab report
# - need to get
# to find out if professors are hubs or not
# does working within NTU = higher top publishing likelihood?
# do NTU profs publish a lot within top journals


# RFE later on

# %%
#list(faculty_graph.nodes)

# %%
# need to scrape correspondly DBL data, then augment them with existing dataset
# have to then decide how we'll be using augment faculty details to connect and generate the network

# %%
# Segment to use previously-extracted DBLP raw data to map collaborations between faculty staff

# Import dblp_df.csv as DF
dblp_df = pd.read_csv('dblp_df.csv')

# Create categorical class counts for each article

# Use categorical class counts to map all related faculty members with a dict

# %%
dblp_multi_df = dblp_df[dblp_df['key'].duplicated(keep=False)]
dblp_multi_df.sort_values(by=['key'])
# Out:
#       f_index              Faculty                               key  \
# 2230       29     Lana Obraztsova     journals/aamas/BannikovaDORR21
# 4221       74  Zinovi Rabinovich      journals/aamas/BannikovaDORR21
# 4512       77         Ong Yew Soon          journals/access/HuLWOZ18
# 4693       80         Wen Yonggang          journals/access/HuLWOZ18
# 4675       80         Wen Yonggang     journals/access/WangHHXNWWK19
# ...       ...                  ...                               ...
# 3456       56       Seah Hock Soon  journals/vlsisp/CheongLSQZTSOK09
# 1868       22       Hui Siu Cheung           journals/www/ChongHYF98
# 3973       68        Yeo Chai Kiat           journals/www/ChongHYF98
# 3964       68        Yeo Chai Kiat             journals/www/PhuaHY00
# 1857       22       Hui Siu Cheung             journals/www/PhuaHY00
#
#            mdate                                              Title  Year  \
# 2230  2021-02-11               Reaching consensus under a deadline.  2021
# 4221  2021-02-11               Reaching consensus under a deadline.  2021
# 4512  2020-08-30  How to Find a Perfect Data Scientist: A Distan...  2018
# 4693  2020-08-30  How to Find a Perfect Data Scientist: A Distan...  2018
# 4675  2020-06-30  A Survey on Consensus Mechanisms and Mining St...  2019
# ...          ...                                                ...   ...
# 3456  2020-03-27  Embedded Computing for Fluorescence Confocal E...  2009
# 1868  2017-05-20  A WWW-Assisted Fax System for Internet Fax-to-...  1998
# 3973  2017-05-20  A WWW-Assisted Fax System for Internet Fax-to-...  1998
# 3964  2017-05-20  A web-based Internet Java Phone for real-time ...  2000
# 1857  2017-05-20  A web-based Internet Java Phone for real-time ...  2000
#
#                               Journal
# 2230  Auton. Agents Multi Agent Syst.
# 4221  Auton. Agents Multi Agent Syst.
# 4512                      IEEE Access
# 4693                      IEEE Access
# 4675                      IEEE Access
# ...                               ...
# 3456         J. Signal Process. Syst.
# 1868                   World Wide Web
# 3973                   World Wide Web
# 3964                   World Wide Web
# 1857                   World Wide Web
#
# [958 rows x 7 columns]

# %%
# get categorical uniques in dataframe
categorical_list = dblp_multi_df['key'].drop_duplicates().tolist()

# create list to store key:f_index_list mappins
key_findex_list = []

# use categorical uniques to return df records
for each in categorical_list:
    # extract f_index values from returned df records into a list
    mappings = dblp_multi_df[dblp_multi_df['key'] == each]['f_index'].tolist()
    # create unique pair-wise combinations for mappings (needed for networkx) 
    mappings_pair = list(combinations(mappings, 2)) 
    key_findex_list.append([mappings_pair, each])

# %%
key_findex_list
# Out:
# [[[(0, 16)], 'journals/tvt/NguyenMN16'],
#  [[(1, 56)], 'journals/cg/SoonS04'],
#  [[(2, 19)], 'journals/cem/ShrivastwaPCSCG20'],
#  [[(2, 5)], 'journals/tc/BhattacharjeeTE20'],
#  [[(2, 59)], 'journals/mam/RaviNBKGC19'],
#  [[(2, 59)], 'journals/iacr/RaviGCKNB19'],
#  [[(2, 59)], 'journals/iacr/RaviGCB19'],
#  [[(2, 27)], 'journals/pieee/BurgCL18'],
#  [[(2, 27)], 'journals/tcas/PudiCL18'],
#  [[(2, 5)], 'journals/corr/abs-1809-08195'],
#  [[(2, 27)], 'journals/corr/abs-1810-00545'],
#  [[(2, 17)], 'journals/cogcom/CambriaCLMW17'],
#  [[(2, 59)], 'journals/ccds/GuptaCK13'],
#  [[(2, 59)], 'journals/tc/GuptaCSMS13'],
#  [[(2, 59)], 'journals/iacr/GuptaCK12'],
#  [[(3, 60)], 'journals/jasis/LiSD13'],
#  [[(3, 60)], 'journals/snam/LiDS12'],
#  [[(5, 64)], 'journals/rts/SamaddarET20'],
#  [[(5, 64)], 'journals/tosn/JiangTE20'],
#  [[(5, 64)], 'journals/corr/abs-2004-06368'],
#  [[(5, 83)], 'journals/corr/abs-2004-14804'],
#  [[(5, 64)], 'journals/corr/abs-2006-15832'],
#  [[(5, 64)], 'journals/sigbed/SamaddarET19'],
#  [[(5, 64)], 'journals/corr/abs-1910-12000'],
#  [[(5, 64)], 'journals/corr/abs-1809-03165'],
#  [[(6, 74)], 'journals/corr/abs-1911-06992'],
#  [[(6, 75)], 'journals/tits/XiongGAMB18'],
#  [[(6, 16), (6, 75), (16, 75)], 'journals/jsac/ChenANSM17'],
#  [[(6, 75)], 'journals/dss/YuSMAL14'],
#  [[(6, 75)], 'journals/tii/AnSMC07'],
#  [[(6, 75)], 'journals/mags/MiaoWGSA06'],
#  [[(6, 75)], 'journals/ieicet/AnMC05'],
#  [[(7, 77)], 'journals/tnn/LiuOC21'],
#  [[(7, 23)], 'journals/ijon/ShiCGJ20'],
#  [[(7, 9), (7, 73), (9, 73)], 'journals/ivc/SongZCC20'],
#  [[(7, 77)], 'journals/tnn/LiuOSC20'],
#  [[(7, 73)], 'journals/tvcg/JiangZ0Z20'],
#  [[(7, 9)], 'journals/corr/abs-2003-03055'],
#  [[(7, 70)], 'journals/corr/abs-2003-03923'],
#  [[(7, 37)], 'journals/corr/abs-2003-09790'],
#  [[(7, 73)], 'journals/corr/abs-2008-05714'],
#  [[(7, 23)], 'journals/corr/abs-2009-14352'],
#  [[(7, 9), (7, 73), (9, 73)], 'journals/cgf/DengZCC19'],
#  [[(7, 73)], 'journals/cgf/NiJCZLL19'],
#  [[(7, 9)], 'journals/ijon/LiuSCCZ19'],
#  [[(7, 37)], 'journals/ivc/WuLC19'],
#  [[(7, 77)], 'journals/kbs/LiuCOW19'],
#  [[(7, 73)], 'journals/pami/GuoZCJZ19'],
#  [[(7, 9)], 'journals/pami/ShengCCPN19'],
#  [[(7, 37)], 'journals/tmm/ZhangLCSSK19'],
#  [[(7, 9), (7, 73), (9, 73)], 'journals/corr/abs-1901-06765'],
#  [[(7, 73)], 'journals/corr/abs-1902-09907'],
#  [[(7, 9)], 'journals/corr/abs-1903-00304'],
#  [[(7, 9)], 'journals/corr/abs-1903-04227'],
#  [[(7, 9)], 'journals/corr/abs-1903-10143'],
#  [[(7, 23)], 'journals/corr/abs-1903-10658'],
#  [[(7, 70)], 'journals/corr/abs-1904-08608'],
#  [[(7, 9)], 'journals/corr/abs-1905-02114'],
#  [[(7, 73)], 'journals/corr/abs-1905-05622'],
#  [[(7, 23)], 'journals/corr/abs-1907-12905'],
#  [[(7, 77)], 'journals/corr/abs-1909-06541'],
#  [[(7, 9), (7, 73), (9, 73)], 'journals/corr/abs-1911-11999'],
#  [[(7, 77)], 'journals/eaai/LiuOCW18'],
#  [[(7, 77)], 'journals/kbs/LiuCO18'],
#  [[(7, 9), (7, 73), (9, 73)], 'journals/pami/XuDZZCC18'],
#  [[(7, 80)], 'journals/tmm/GaoZHWCLZ18'],
#  [[(7, 9)], 'journals/tomccap/WangCLC18'],
#  [[(7, 9)], 'journals/corr/abs-1802-07421'],
#  [[(7, 37)], 'journals/corr/abs-1803-02563'],
#  [[(7, 23)], 'journals/corr/abs-1803-05526'],
#  [[(7, 73)], 'journals/corr/abs-1803-06802'],
#  [[(7, 23)], 'journals/corr/abs-1803-07464'],
#  [[(7, 77)], 'journals/corr/abs-1806-00720'],
#  [[(7, 77)], 'journals/corr/abs-1807-01065'],
#  [[(7, 23)], 'journals/corr/abs-1807-03658'],
#  [[(7, 70)], 'journals/corr/abs-1808-00171'],
#  [[(7, 9)], 'journals/corr/abs-1808-01454'],
#  [[(7, 73)], 'journals/corr/abs-1808-05323'],
#  [[(7, 37)], 'journals/corr/abs-1809-05285'],
#  [[(7, 77)], 'journals/corr/abs-1811-01159'],
#  [[(7, 77)], 'journals/corr/abs-1811-01179'],
#  [[(7, 37)], 'journals/corr/abs-1811-08599'],
#  [[(7, 70)], 'journals/corr/abs-1812-02378'],
#  [[(7, 77)], 'journals/cce/LiuCO17'],
#  [[(7, 80)], 'journals/ieeemm/GaoWC17'],
#  [[(7, 9), (7, 73), (9, 73)], 'journals/ivc/DengCCZ17'],
#  [[(7, 80)], 'journals/tcc/LuFWC17'],
#  [[(7, 77)], 'journals/corr/YangZCO17'],
#  [[(7, 45)], 'journals/corr/PolzounovAELC17'],
#  [[(7, 45)], 'journals/corr/AblavatskiLC17'],
#  [[(7, 73)], 'journals/corr/abs-1708-00980'],
#  [[(7, 23)], 'journals/corr/abs-1711-06420'],
#  [[(7, 45)], 'journals/jvcir/ZhuMCL16'],
#  [[(7, 45), (7, 73), (45, 73)], 'journals/tmm/ZhuLCZLM16'],
#  [[(7, 9)], 'journals/jstsp/ZhaoFCC15'],
#  [[(7, 39)], 'journals/jvcir/ChenCLS15'],
#  [[(7, 9)], 'journals/tip/0001LCWC15'],
#  [[(7, 9), (7, 73), (9, 73)], 'journals/tist/ChenCZCS15'],
#  [[(7, 9)], 'journals/tmm/0001LCCW15'],
#  [[(7, 73)], 'journals/vc/DuanCZ15'],
#  [[(7, 45)], 'journals/corr/ZhuMCL15'],
#  [[(7, 9)], 'journals/corr/PhamCDPCC15'],
#  [[(7, 45)], 'journals/corr/ZhuLCL15'],
#  [[(7, 73)], 'journals/tog/XiongZZCL14'],
#  [[(7, 80)], 'journals/tvt/ZhangWCW14'],
#  [[(7, 73)], 'journals/jvcir/AnhCZL13'],
#  [[(7, 73)], 'journals/tip/ZhuZCM13'],
#  [[(7, 73)], 'journals/tip/AnhCZZ12'],
#  [[(7, 39)], 'journals/tmm/DengLC12'],
#  [[(7, 73)], 'journals/tog/ZhangZWC12'],
#  [[(7, 73)], 'journals/cgf/DuanZC11'],
#  [[(7, 16)], 'journals/tmm/GuoFCNW11'],
#  [[(7, 73)], 'journals/tvcg/ZhangZC11'],
#  [[(7, 73)], 'journals/cgf/ZhangWCZT10'],
#  [[(7, 73)], 'journals/tcsv/GuanCZZ10'],
#  [[(7, 73)], 'journals/tip/YangCZL10'],
#  [[(7, 39)], 'journals/jvcir/ZhaiLCYZ09'],
#  [[(7, 73)], 'journals/tip/YangZCRC09'],
#  [[(7, 39)], 'journals/tbc/ZhaiCLYZ08'],
#  [[(7, 73)], 'journals/tmm/GuanCZC08'],
#  [[(7, 39)], 'journals/tmm/ZhaiCLYZE08'],
#  [[(7, 11), (7, 14), (11, 14)], 'journals/tcsv/TaoCYRCN06'],
#  [[(8, 65)], 'journals/tpds/LiZT0L0G21'],
#  [[(8, 77)], 'journals/tsmc/ZhongFCO20'],
#  [[(8, 65)], 'journals/tpds/LiTCTLW19'],
#  [[(8, 65)], 'journals/tmm/DengLSTC18'],
#  [[(8, 65)], 'journals/tomccap/LiDTCL018'],
#  [[(8, 65)], 'journals/ton/RenTLC17'],
#  [[(8, 77)], 'journals/tec/ZhongOC16'],
#  [[(8, 65)], 'journals/tpds/LiTC16'],
#  [[(8, 65)], 'journals/tcsv/LiTC15'],
#  [[(8, 65)], 'journals/fgcs/TangCG14'],
#  [[(8, 65)], 'journals/simulation/LiTCL13'],
#  [[(8, 65)], 'journals/jos/LiCTZ12'],
#  [[(8, 65)], 'journals/tpds/DuongNZTCA12'],
#  [[(8, 65)], 'journals/jnca/DuongZCTA11'],
#  [[(8, 77)], 'journals/tec/AydtTCLOA11'],
#  [[(8, 31)], 'journals/concurrency/XavierCL09'],
#  [[(8, 31)], 'journals/tomccap/ZhouCTLW07'],
#  [[(8, 31)], 'journals/tjs/XavierCL06'],
#  [[(8, 61)], 'journals/tochi/SunXSCSC06'],
#  [[(8, 31)], 'journals/tjs/ZhuCLW05'],
#  [[(8, 31)], 'journals/tomacs/CaiTLZ05'],
#  [[(8, 31)], 'journals/fgcs/ZengCTZL04'],
#  [[(8, 31)], 'journals/pc/ZhuKCL04'],
#  [[(8, 31)], 'journals/tomacs/ZhouCLT04'],
#  [[(8, 31)], 'journals/cluster/ZhuCL03'],
#  [[(8, 31)], 'journals/jpdc/CaiLZ02'],
#  [[(8, 31)], 'journals/jpdc/GuLC01'],
#  [[(8, 21)], 'journals/scpe/GanLCTJHH01'],
#  [[(8, 31)], 'journals/sigops/LeeCTK01'],
#  [[(8, 61)], 'journals/pc/CaiZTS99'],
#  [[(8, 31)], 'journals/ppl/LeeGCH99'],
#  [[(8, 31)], 'journals/sigops/GuLC99'],
#  [[(8, 21)], 'journals/simulation/LowLCHHJT99'],
#  [[(8, 31)], 'journals/infsof/CaiL98'],
#  [[(8, 31)], 'journals/ppl/LeeHCT96'],
#  [[(10, 31)], 'journals/jnca/AngCL98'],
#  [[(11, 14)], 'journals/tip/RenGCR13'],
#  [[(11, 62)], 'journals/mta/WanTLC12'],
#  [[(11, 39)], 'journals/taslp/NarwariaLMEC12'],
#  [[(11, 39)], 'journals/tip/NarwariaLMEC12'],
#  [[(11, 14)], 'journals/ijon/SunRC10'],
#  [[(11, 62)], 'journals/informaticaSI/WangJCT10'],
#  [[(11, 14)], 'journals/cviu/HuRC09'],
#  [[(11, 14), (11, 62), (14, 62)], 'journals/tmm/HuCCXRT09'],
#  [[(11, 14)], 'journals/jvcir/HuRC08'],
#  [[(11, 14)], 'journals/ejasp/LiuXYCR06'],
#  [[(11, 14)], 'journals/is/YiRC06'],
#  [[(11, 14)], 'journals/ivc/YiRC06'],
#  [[(11, 31)], 'journals/itpro/ZhouCL05'],
#  [[(11, 31)], 'journals/jwsr/ZhouCL05'],
#  [[(11, 14)], 'journals/mta/YiRC05'],
#  [[(11, 14)], 'journals/prl/YiRC05'],
#  [[(11, 31)], 'journals/jwsr/ZhouCL04'],
#  [[(11, 31)], 'journals/ijcomsys/LouCLW01'],
#  [[(12, 60)], 'journals/corr/abs-2012-06780'],
#  [[(12, 60)], 'journals/corr/abs-2012-13873'],
#  [[(12, 31)], 'journals/spe/TanTCLLDCXN13'],
#  [[(13, 43)], 'journals/pvldb/WangLCL20'],
#  [[(13, 43)], 'journals/corr/abs-2003-02542'],
#  [[(13, 43)], 'journals/corr/abs-1902-10928'],
#  [[(13, 60)], 'journals/tkde/HanSCZJP18'],
#  [[(13, 43)], 'journals/corr/abs-1812-06668'],
#  [[(13, 75)], 'journals/tkde/HaiCCCM17'],
#  [[(13, 75)], 'journals/tkde/WeiCMZL16'],
#  [[(13, 60)], 'journals/tois/YuanCZMS15'],
#  [[(13, 60)], 'journals/jasis/MaSC13'],
#  [[(13, 60)], 'journals/jasis/QuCLSC12'],
#  [[(14, 54)], 'journals/tits/PrasadDRQ20'],
#  [[(14, 31)], 'journals/mva/LiuLRSM19'],
#  [[(14, 54)], 'journals/tits/PrasadPRRRQ19'],
#  [[(14, 54)], 'journals/corr/abs-1809-04659'],
#  [[(14, 54)], 'journals/tits/PrasadRRRQ17'],
#  [[(14, 54)], 'journals/corr/PrasadRPRRQ17'],
#  [[(14, 54)], 'journals/corr/PrasadPRRRQ17'],
#  [[(14, 54)], 'journals/corr/PrasadPRRRQ16'],
#  [[(14, 54)], 'journals/corr/PrasadRRRQ16'],
#  [[(15, 54)], 'journals/ijfsa/QuekGM11'],
#  [[(15, 54)], 'journals/tsmc/GohQM10'],
#  [[(16, 27), (16, 72), (27, 72)], 'journals/iotj/MollahZNLZGKY21'],
#  [[(16, 64), (16, 72), (64, 72)], 'journals/iotj/ZhaoZJTNLLL21'],
#  [[(16, 72)], 'journals/twc/YangXZNXW21'],
#  [[(16, 75)], 'journals/comsur/LimLHJLYNM20'],
#  [[(16, 75)], 'journals/iotj/LimXMN0LP20'],
#  [[(16, 72)], 'journals/network/YangAXNZW20'],
#  [[(16, 72)], 'journals/tnse/XiongZNDZ20'],
#  [[(16, 80)], 'journals/tsc/HuWYQN20'],
#  [[(16, 72)], 'journals/corr/abs-2001-09259'],
#  [[(16, 72)], 'journals/corr/abs-2001-10845'],
#  [[(16, 72)], 'journals/corr/abs-2002-00331'],
#  [[(16, 75)], 'journals/corr/abs-2004-03877'],
#  [[(16, 27), (16, 72), (27, 72)], 'journals/corr/abs-2004-08856'],
#  [[(16, 72)], 'journals/corr/abs-2004-09059'],
#  [[(16, 75)], 'journals/corr/abs-2006-00511'],
#  [[(16, 27), (16, 72), (27, 72)], 'journals/corr/abs-2007-06022'],
#  [[(16, 75)], 'journals/corr/abs-2007-06378'],
#  [[(16, 75)], 'journals/corr/abs-2008-04743'],
#  [[(16, 75)], 'journals/corr/abs-2008-09048'],
#  [[(16, 72)], 'journals/corr/abs-2010-08947'],
#  [[(16, 72)], 'journals/corr/abs-2012-08989'],
#  [[(16, 80)], 'journals/access/WangHHXNWWK19'],
#  [[(16, 72)], 'journals/tvt/KangXNYKZ19'],
#  [[(16, 64), (16, 72), (64, 72)], 'journals/corr/abs-1906-10893'],
#  [[(16, 72)], 'journals/corr/abs-1907-08927'],
#  [[(16, 75)], 'journals/corr/abs-1909-11875'],
#  [[(16, 72)], 'journals/corr/abs-1910-09172'],
#  [[(16, 72)], 'journals/corr/abs-1910-14383'],
#  [[(16, 27), (16, 72), (27, 72)], 'journals/corr/abs-1911-03298'],
#  [[(16, 72)], 'journals/corr/abs-1912-05744'],
#  [[(16, 80)], 'journals/corr/abs-1805-02707'],
#  [[(16, 72)], 'journals/corr/abs-1809-08387'],
#  [[(16, 80)], 'journals/comsur/LuongWNWH17'],
#  [[(16, 80)], 'journals/jsac/HuWN17'],
#  [[(16, 80)], 'journals/jsac/HuWN17a'],
#  [[(16, 80)], 'journals/corr/LuongWNWH17'],
#  [[(16, 64)], 'journals/corr/abs-1712-06056'],
#  [[(16, 80)], 'journals/comsur/XiaWFNX15'],
#  [[(16, 31)], 'journals/tsc/KaewpuangCNLW14'],
#  [[(16, 31)], 'journals/tsc/ChaisiriLN12'],
#  [[(16, 75)], 'journals/pieee/YuSMLN10'],
#  [[(17, 77)], 'journals/jaihc/ValdiviaMCLCOH20'],
#  [[(17, 55)], 'journals/corr/abs-1810-06818'],
#  [[(17, 55)], 'journals/corr/abs-1811-03325'],
#  [[(17, 77)], 'journals/kbs/ChaturvediOTWC16'],
#  [[(17, 77)], 'journals/expert/CambriaHKZVLYCLLLFOLALCNMGZDYMOJTTKYCL13'],
#  [[(18, 54)], 'journals/isci/ZhangMQG17'],
#  [[(19, 54)], 'journals/tbe/FoongTCCAQGPKVY20'],
#  [[(19, 54)], 'journals/nca/ArvanehGAQ14'],
#  [[(19, 54)], 'journals/isci/TungQG13'],
#  [[(19, 54)], 'journals/neco/ArvanehGAQ13'],
#  [[(19, 54)], 'journals/tnn/ArvanehGAQ13'],
#  [[(19, 54)], 'journals/eswa/TungQG12'],
#  [[(19, 54)], 'journals/tbe/ArvanehGAQ11'],
#  [[(19, 54)], 'journals/tnn/TungQG11'],
#  [[(22, 84)], 'journals/corr/abs-1905-10847'],
#  [[(22, 84)], 'journals/corr/abs-1906-04393'],
#  [[(22, 72)], 'journals/corr/abs-1907-00782'],
#  [[(22, 84)], 'journals/es/FangTHW18'],
#  [[(22, 84)], 'journals/ipm/FangTHW18'],
#  [[(22, 84)], 'journals/corr/abs-1801-00102'],
#  [[(22, 84)], 'journals/corr/abs-1801-09251'],
#  [[(22, 84)], 'journals/corr/abs-1803-09074'],
#  [[(22, 84)], 'journals/corr/abs-1805-02856'],
#  [[(22, 84)], 'journals/corr/abs-1805-11535'],
#  [[(22, 84)], 'journals/corr/abs-1806-00778'],
#  [[(22, 84)], 'journals/corr/abs-1810-02938'],
#  [[(22, 84)], 'journals/corr/abs-1811-04210'],
#  [[(22, 84)], 'journals/corr/abs-1811-09786'],
#  [[(22, 84)], 'journals/corr/TayLH17'],
#  [[(22, 84)], 'journals/corr/TayPLH17'],
#  [[(22, 84)], 'journals/corr/TayLH17a'],
#  [[(22, 84)], 'journals/corr/abs-1708-04828'],
#  [[(22, 84)], 'journals/corr/abs-1711-04981'],
#  [[(22, 84)], 'journals/corr/abs-1711-07656'],
#  [[(22, 84)], 'journals/corr/abs-1712-05403'],
#  [[(22, 84)], 'journals/tacl/LuuHN16'],
#  [[(22, 31), (22, 68), (31, 68)], 'journals/comcom/YeoHSL01'],
#  [[(22, 68)], 'journals/mam/YeoHSL01'],
#  [[(22, 68)], 'journals/www/PhuaHY00'],
#  [[(22, 68)], 'journals/cas/ChongHY99'],
#  [[(22, 68)], 'journals/mam/FooYHX99'],
#  [[(22, 68)], 'journals/nis/HuiYJ99'],
#  [[(22, 68)], 'journals/www/ChongHYF98'],
#  [[(22, 68)], 'journals/mam/FooYH97'],
#  [[(23, 75)], 'journals/corr/abs-2011-01549'],
#  [[(25, 64)], 'journals/corr/abs-1902-07057'],
#  [[(26, 39)], 'journals/cmpb/NiwasJLKSAVC16'],
#  [[(26, 39)], 'journals/cmpb/NiwasLBKKSAC16'],
#  [[(26, 39)], 'journals/jms/BaiNLJKWSAC16'],
#  [[(26, 39)], 'journals/titb/NiwasLKKSAC16'],
#  [[(26, 39)], 'journals/jms/NiwasLBKSAC15'],
#  [[(26, 77)], 'journals/cim/EllabaanOHKM13'],
#  [[(26, 77)], 'journals/cma/EllabaanHOKBEM12'],
#  [[(26, 77)], 'journals/tcbb/HandokoOSKO12'],
#  [[(26, 77)], 'journals/tcbb/HandokoOSKO12a'],
#  [[(26, 77)], 'journals/tec/HandokoKO10'],
#  [[(27, 49)], 'journals/corr/abs-2101-04194'],
#  [[(27, 72)], 'journals/corr/abs-2008-03686'],
#  [[(27, 72)], 'journals/corr/abs-2011-14197'],
#  [[(27, 72)], 'journals/corr/abs-1911-12060'],
#  [[(28, 76)], 'journals/jce/AlamMKLS20'],
#  [[(28, 76)], 'journals/tecs/KadiyalaJLS20'],
#  [[(28, 76)], 'journals/cj/WuCWJLS18'],
#  [[(28, 76)], 'journals/tvlsi/PrakashCLS18'],
#  [[(28, 76)], 'journals/tits/WuLS17'],
#  [[(28, 76)], 'journals/cee/ShiWLS16'],
#  [[(28, 76)], 'journals/jrtip/RamakrishnanWLS16'],
#  [[(28, 76)], 'journals/tits/WuLS15'],
#  [[(28, 76)], 'journals/tjs/JiangWLSS15'],
#  [[(28, 76)], 'journals/jolpe/AungLS14'],
#  [[(28, 76)], 'journals/tecs/LamSC14'],
#  [[(28, 76)], 'journals/tjs/WuJSLSS14'],
#  [[(28, 76)], 'journals/trets/LamCS14'],
#  [[(28, 76)], 'journals/jcp/LiuLSY13'],
#  [[(28, 76)], 'journals/mam/PrakashLCS13'],
#  [[(28, 76)], 'journals/tjs/WuWLS13'],
#  [[(28, 76)], 'journals/ijprai/LiuLSY12'],
#  [[(28, 76)], 'journals/tc/LamSC11'],
#  [[(28, 76)], 'journals/jsa/LiJLSL10'],
#  [[(28, 76)], 'journals/ijict/LamFSJ09'],
#  [[(28, 76)], 'journals/jsa/LamS09'],
#  [[(28, 76)], 'journals/tie/LamSC09'],
#  [[(28, 76)], 'journals/scpe/ChuongLS07'],
#  [[(28, 76)], 'journals/ijhr/LimLTS06'],
#  [[(28, 76)], 'journals/mam/LamSC06'],
#  [[(28, 76)], 'journals/ras/LamSS05'],
#  [[(28, 76)], 'journals/tc/SrikanthanLS04'],
#  [[(28, 76)], 'journals/tie/LamSS04'],
#  [[(28, 76)], 'journals/jirs/LamS02'],
#  [[(28, 76)], 'journals/mam/LamS02'],
#  [[(28, 76)], 'journals/jirs/LamS01'],
#  [[(28, 76)], 'journals/comcom/LamS00'],
#  [[(29, 74)], 'journals/aamas/BannikovaDORR21'],
#  [[(29, 74)], 'journals/ai/ElkindGORV21'],
#  [[(29, 74)], 'journals/corr/abs-1905-04933'],
#  [[(29, 74)], 'journals/corr/abs-1905-07173'],
#  [[(29, 74)], 'journals/corr/abs-1906-07071'],
#  [[(29, 74)], 'journals/corr/abs-1911-12472'],
#  [[(31, 68)], 'journals/ijitn/YeanLY20'],
#  [[(31, 68)], 'journals/cn/ChenYLL18'],
#  [[(31, 68)], 'journals/dke/ChenYLL18'],
#  [[(31, 68)], 'journals/ijon/ChenYLLJ18'],
#  [[(31, 75)], 'journals/ml/ZhangZHSLMH18'],
#  [[(31, 68)], 'journals/prl/ChenZYLL18'],
#  [[(31, 50), (31, 66), (31, 68), (50, 66), (50, 68), (66, 68)],
#   'journals/titb/SeanglidetLYVO18'],
#  [[(31, 68)], 'journals/compsec/ChenYLL17'],
#  [[(31, 35)], 'journals/spe/LiangLH14'],
#  [[(31, 39)], 'journals/tcsv/PaulLLL14'],
#  [[(31, 68)], 'journals/cn/YangYL13'],
#  [[(31, 68)], 'journals/comcom/ZhongYL13'],
#  [[(31, 39)], 'journals/ejasp/PaulLLL13'],
#  [[(31, 39)], 'journals/ejasp/PaulLLL13a'],
#  [[(31, 68)], 'journals/tvt/YangYL13'],
#  [[(31, 68)], 'journals/cj/0002BGBYL12'],
#  [[(31, 68)], 'journals/jnca/ZhongYL12'],
#  [[(31, 68)], 'journals/jnca/BanerjeeFYL12'],
#  [[(31, 39)], 'journals/tip/GuLLL12'],
#  [[(31, 39)], 'journals/tip/GuLLLS12'],
#  [[(31, 39)], 'journals/tip/GuLLL12a'],
#  [[(31, 68)], 'journals/tmc/YangYL12'],
#  [[(31, 39)], 'journals/tmm/FangLLLCL12'],
#  [[(31, 39)], 'journals/tmm/DengLLL12'],
#  [[(31, 68)], 'journals/tvt/Banerjee0GYAL12'],
#  [[(31, 68)], 'journals/corr/abs-1203-1185'],
#  [[(31, 39)], 'journals/jvcir/DengLLLS11'],
#  [[(31, 35)], 'journals/jwsr/LiangBL11'],
#  [[(31, 39)], 'journals/tcsv/PaulLLL11'],
#  [[(31, 39)], 'journals/tip/PaulLLL11'],
#  [[(31, 65), (31, 68), (65, 68)], 'journals/tjs/ZhangLTY11'],
#  [[(31, 68)], 'journals/corr/abs-1109-5338'],
#  [[(31, 68)], 'journals/corr/abs-1109-5959'],
#  [[(31, 68)], 'journals/corr/abs-1111-4807'],
#  [[(31, 68)], 'journals/cn/SantosaLY10'],
#  [[(31, 68)], 'journals/comcom/AndiYL10'],
#  [[(31, 65), (31, 68), (65, 68)], 'journals/fgcs/ZhangLTY10'],
#  [[(31, 68)], 'journals/jnca/ZhongYL10'],
#  [[(31, 68)], 'journals/tvt/BanerjeeTFYL10'],
#  [[(31, 75)], 'journals/ijon/SongMSML09'],
#  [[(31, 68)], 'journals/telsys/LimLYTX09'],
#  [[(31, 68)], 'journals/tmc/LimYLL09'],
#  [[(31, 75)], 'journals/ijwet/LeongML08'],
#  [[(31, 77)], 'journals/fgcs/LimOJSL07'],
#  [[(31, 68)], 'journals/icl/TantraLLY07'],
#  [[(31, 77)], 'journals/soco/ZhouOLL07'],
#  [[(31, 68)], 'journals/tmm/LimLY07'],
#  [[(31, 65), (31, 68), (65, 68)], 'journals/fgcs/TangLTY06'],
#  [[(31, 77)], 'journals/gpem/LimOJSL06'],
#  [[(31, 68)], 'journals/ieicet/LimLY06'],
#  [[(31, 68)], 'journals/comcom/LimLY05'],
#  [[(31, 65), (31, 68), (65, 68)], 'journals/fgcs/TangLYT05'],
#  [[(31, 68)], 'journals/comcom/YeoLE04'],
#  [[(31, 68)], 'journals/sigops/LeeWYLLHS04'],
#  [[(31, 68)], 'journals/jnca/YeoLE03'],
#  [[(31, 68)], 'journals/jnsm/LimLY03'],
#  [[(31, 68)], 'journals/mta/LeeKYKW03'],
#  [[(31, 68)], 'journals/jnca/LeeYF02'],
#  [[(31, 68)], 'journals/sigops/OngLLY02'],
#  [[(31, 68)], 'journals/sigops/YeoLE02'],
#  [[(31, 68)], 'journals/ijcomsys/LeeYPS01'],
#  [[(31, 68)], 'journals/cn/PoonJLY00'],
#  [[(31, 66)], 'journals/jnca/LeeLV00'],
#  [[(31, 68)], 'journals/jocec/SunLY00'],
#  [[(31, 68)], 'journals/tce/PoonLY00'],
#  [[(31, 68)], 'journals/tce/PoonLY99'],
#  [[(37, 39)], 'journals/corr/abs-2101-02412'],
#  [[(37, 39)], 'journals/tmm/YangLJL20'],
#  [[(37, 75)], 'journals/corr/abs-2007-13374'],
#  [[(37, 75)], 'journals/corr/abs-2009-00944'],
#  [[(37, 64)], 'journals/corr/abs-2012-07626'],
#  [[(37, 64)], 'journals/corr/abs-1902-05197'],
#  [[(37, 39)], 'journals/corr/abs-1903-08836'],
#  [[(37, 39)], 'journals/corr/abs-1904-03571'],
#  [[(37, 39)], 'journals/corr/abs-1805-08365'],
#  [[(38, 39)], 'journals/corr/abs-2007-07097'],
#  [[(38, 39)], 'journals/corr/abs-2009-09231'],
#  [[(39, 80)], 'journals/tcsv/BoulgourisBCCCR16'],
#  [[(39, 56)], 'journals/spic/DongFLDZS15'],
#  [[(39, 56)], 'journals/tmm/DongFLS15'],
#  [[(39, 56)], 'journals/jvcir/DongLFWS14'],
#  [[(39, 76)], 'journals/tip/ShaoLGJS13'],
#  [[(39, 56)], 'journals/sigpro/LiuSZLT12'],
#  [[(44, 77)], 'journals/corr/abs-2006-10645'],
#  [[(44, 68)], 'journals/corr/abs-2007-14878'],
#  [[(44, 77)], 'journals/corr/abs-2008-11702'],
#  [[(47, 77)], 'journals/ijon/AshfahaniPLO20'],
#  [[(47, 77)], 'journals/corr/abs-1910-03437'],
#  [[(47, 77)], 'journals/corr/abs-1910-04062'],
#  [[(47, 77)], 'journals/corr/abs-1809-09081'],
#  [[(49, 60)], 'journals/kais/LiNS05'],
#  [[(49, 60)], 'journals/tkde/SunLNS04'],
#  [[(49, 60)], 'journals/jasis/SunLN03'],
#  [[(52, 75)], 'journals/ai/QianPM21'],
#  [[(52, 60)], 'journals/tmc/WangLPS19'],
#  [[(53, 56)], 'journals/vc/CaiLLQS17'],
#  [[(53, 56)], 'journals/cii/ChiewLQS14'],
#  [[(53, 56)], 'journals/jwscg/MovaniaLQCS12'],
#  [[(53, 56)], 'journals/vlsisp/CheongLSQZTSOK09'],
#  [[(54, 62), (54, 75), (62, 75)], 'journals/ijon/WangQQTMZNZ18'],
#  [[(56, 73)], 'journals/cg/WangZS19'],
#  [[(56, 76)], 'journals/mam/SrikanthanCSL95'],
#  [[(59, 77)], 'journals/corr/abs-1811-06632'],
#  [[(60, 65)], 'journals/vldb/HuangTHXCSTL20'],
#  [[(60, 65)], 'journals/corr/abs-2004-06469'],
#  [[(60, 65)], 'journals/corr/abs-1907-09668'],
#  [[(60, 65)], 'journals/pvldb/HanHXTST18'],
#  [[(60, 65)], 'journals/tkde/YaoTLS06'],
#  [[(62, 75)], 'journals/ijon/WangWPMTZ20'],
#  [[(62, 75)], 'journals/nca/WangWZPMTZ20'],
#  [[(62, 75)], 'journals/ijon/ParmarWZTMJZ19'],
#  [[(62, 75)], 'journals/nn/MengTM19'],
#  [[(62, 77)], 'journals/memetic/FengOTT15'],
#  [[(62, 77)], 'journals/nca/KanLOTY13'],
#  [[(62, 77)], 'journals/corr/abs-1207-0702'],
#  [[(62, 77)], 'journals/eswa/TanOT11'],
#  [[(62, 75), (62, 82), (75, 82)], 'journals/cga/CaiMTSL10'],
#  [[(62, 77)], 'journals/ijon/TanFO10'],
#  [[(62, 77)], 'journals/ijon/RongOTZ08'],
#  [[(64, 80)], 'journals/tpds/YiZWT20'],
#  [[(64, 80)], 'journals/corr/abs-2001-10681'],
#  [[(64, 80)], 'journals/corr/abs-2012-06834'],
#  [[(70, 75)], 'journals/corr/abs-2004-00900'],
#  [[(75, 82)], 'journals/corr/abs-2102-02515'],
#  [[(75, 82)], 'journals/corr/abs-2012-01675'],
#  [[(77, 80)], 'journals/access/HuLWOZ18'],
#  [[(77, 80)], 'journals/fcsc/XuAYWOX15']]

# %%
# iterate over key_findex_list to populate initial network

for each in key_findex_list:
    faculty_graph.add_edges_from(each[0], label=each[1])

# %%
# Set figure for graph
plt.figure(figsize=(35, 20))

# Draw the graph
nx.draw(faculty_graph, with_labels=True, font_size=10,
        node_color='red', font_color='white', edge_color='grey', node_size=250)

# Save the graph
plt.savefig("collab_graph.png", dpi=326)

# %%
# Remove isolates
faculty_graph.remove_nodes_from(list(nx.isolates(faculty_graph)))

# %%
# Set figure for graph
plt.figure(figsize=(15, 10))

# Draw the graph (with isolates removed)
nx.draw(faculty_graph, with_labels=True, font_size=10,
        node_color='red', font_color='white', edge_color='grey', node_size=300)

# Save the graph
plt.savefig("collab_graph_connected_only.png", dpi=326)
